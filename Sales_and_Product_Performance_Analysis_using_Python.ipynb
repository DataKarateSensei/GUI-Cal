# %% [markdown]
# <a href="https://colab.research.google.com/github/gitLamda/GUI-Cal/blob/main/Sales_and_Product_Performance_Analysis_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import string
import matplotlib
import matplotlib.pyplot as plt
import random
import seaborn as sns

# %%
products=["Product A","Product B","Product C","Product D","Product E"]
Area=["Colombo","Jaffna","Kandy","Galle","Anuradhapura"]
date=pd.date_range('2022-01-01', '2022-01-31', freq='D')

# %%
#creating probable values for columns in the data frame
def generate_random_prodID():
  return random.choices(products,weights=[0.15,0.32,0.28,0.20,0.05])
def generate_random_sales_quantity():
  return int(random.uniform(50,100))
def generate_random_date():
  return random.choice(date)
def generate_random_area():
  return random.choice(Area)

# %%
#Creating the data frame for 100 records
total_number_of_transactions=100
data=[]
for i in range(total_number_of_transactions):
  row=[]
  row.append(generate_random_prodID())
  row.append(generate_random_sales_quantity())
  row.append(generate_random_date())
  row.append(generate_random_area())
  data.append(row)
df=pd.DataFrame(data,columns=["Product ID","Sales Quan","Transaction Date","Sales Area"])
df
# Out:
#      Product ID  Sales Quan Transaction Date    Sales Area
# 0   [Product D]          73       2022-08-01         Galle
# 1   [Product C]          72       2022-06-18         Galle
# 2   [Product B]          77       2022-06-18         Kandy
# 3   [Product B]          80       2022-04-09         Galle
# 4   [Product B]          83       2022-08-17         Kandy
# ..          ...         ...              ...           ...
# 95  [Product C]          80       2022-01-04        Jaffna
# 96  [Product B]          77       2022-02-12  Anuradhapura
# 97  [Product B]          82       2022-03-19       Colombo
# 98  [Product C]          74       2022-04-28  Anuradhapura
# 99  [Product B]          77       2022-07-23         Kandy
#
# [100 rows x 4 columns]

# %%
#Creating a Pie Chart for Sales Quantity by Area
sales_quan_by_area=df.groupby(["Sales Area"]).sum()
sales_quan_by_area
# Out:
# <ipython-input-15-d56a58717a75>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales_quan_by_area=df.groupby(["Sales Area"]).sum()
#               Sales Quan
# Sales Area
# Anuradhapura        1036
# Colombo             1788
# Galle               1934
# Jaffna              1228
# Kandy               1480

# %%
plt.pie(sales_quan_by_area["Sales Quan"],labels=sales_quan_by_area.index)
plt.title("Sales by Region")
plt.show()

# %%
home=[20, 34, 30, 35, 27]
elec=[25, 32, 34, 20, 25]

# %%
#creating a grouped bar chart for Sales by Region
x=np.arange(len(Area))
width=0.35

fig, ax=plt.subplots()
rects1 = ax.bar(x - width/2, home, width, label='Home Supplies')
rects2 = ax.bar(x + width/2, elec, width, label='Electronics')

ax.set_ylabel("Sales")
ax.set_title("Sales for Home Suppies & Electronics by Region")
ax.set_xticks(x)
ax.set_xticklabels(Area)
ax.legend()

fig.tight_layout()

plt.show()

# %%
import plotly.express as px

fig = px.scatter(df, x='Sales Area',y="Sales Quan",title='Product Performance')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
